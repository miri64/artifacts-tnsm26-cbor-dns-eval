# %%
# %load_ext jupyter_tikz

# %%
# see https://github.com/lucaslrodri/jupyter-tikz/issues/6
preamble = r"\usepackage[T1]{fontenc}\usepackage[tt=false,type1=true]{libertine}\usepackage[varqu]{zi4}\usepackage[libertine]{newtxmath}\usepackage{tikz}\usetikzlibrary{calc,colorbrewer,fit,positioning}"

# %% [markdown]
# Background
# ==========

# %% [markdown]
# ## An Integer

# %%
# %%tikz -p $preamble
# \input{02_background/figs/cbor-example-sint.tex}

# %% [markdown]
# ## A String

# %%
# %%tikz -p $preamble
# \input{02_background/figs/cbor-example-str.tex}
